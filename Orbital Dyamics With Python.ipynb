# %% [markdown]
# # Orbital Dynamics with Python
# This document is intended to provide a short explaination of the use of Python code to model orbitals and calculate orbital elements. The intended conlucion of the activity is to use NASA open data and python to plot example orbits flown by real spacecraft.
#
# >An orbit is a regular, repeating path that one object in space takes around another one.
#
# >Planets, comets, asteroids and other objects in the solar system orbit the sun. Most of the objects orbiting the sun move along or close to an imaginary flat surface. This imaginary surface is called the ecliptic plane.
# -- NASA.gov
#
# # OrbitalPY
# The python library we'll be using is the OrbitalPy code library which can be installed into your python environment using the standard pip install in your command promp (if using windows)
# ```
# pip install orbitalpy
# ```
# we will also want to invoke other libraries such as matplotlib.pyplot, and scipy.constants which will add various other components of functionality.

# %%
import matplotlib.pyplot as plt
from scipy.constants import kilo

# %% [markdown]
# In the code above we have imported the `matplotlib.pyplot` library which helps with plotting the orbital pathways, and we have also imported `kilo` from `scipy.constants` this is the kilometer constant which enables us to plot orbits with actual phyical units.

# %%
from orbital import KeplerianElements, earth, Maneuver, plot

# %% [markdown]
# We have now imported the basic elements from the `orbital` python library.
# `KeplerianElements` utilises the Keplerian orbital elements which include orbital inclination, semimajor axis and period.

# %%
orbit_one = KeplerianElements.with_altitude(5000*kilo, body=earth)
plot(orbit_one)
plt.title("Basic Orbit")
plt.show()

# %% [markdown]
# Here we have created the variable `orbit_one` with the parameters of the `KeplerianElements.with_altitude` this instructs the `OrbitalPy` library to create an orbit with an initial altitude of 5,000km and the `body=earth` refers to the body around which the orbit occurs.

# %%
orbit_two = KeplerianElements.with_altitude(10000*kilo, body = earth)
plot(orbit_two)
plt.title("Orbtit with altitude of 10,000km")
plt.show()
